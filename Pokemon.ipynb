# %%
import pandas as pd

# %%
 df = pd.read_csv('pokemon/pokemon_data.csv') #df_xlsx = pd.read_excel('pokemon/pokemon_data.xlsx')

# %%
df     #df.head(3) #df.tail(3)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#read headers
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#read each column
#df['Name'][0:5] or #df.Name 
#df[['Name','Type 1', 'HP']]

#read each row
#df.head (4) or use the iloc function
#df.iloc[0:4]
#for index, row in df.iterrows():
#    print(index, row['Name'])

#df.loc is used to find "specific data" in the database
#df.loc[df['Type 1'] == "Grass"]

#read a specific location (R,C) trying to bring up venusaur
#df.iloc[2,1]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#sorting/describing data 

#df.describe()

#df.sort_values('Name', ascending=False) #so that you get the table in a descending order

#df.sort_values(['Type 1', 'HP'], ascending=False)
#df.sort_values(['Type 1', 'HP'], ascending=[1,0]) #type 1 will be asc and type 2 will be desc
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#making changes to the data
#df.head(5)
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed'] 

#creating a new column called total to calculate the listed columns

# to drop a column
#df.head(5)

#add a column
#df['Total'] = df.iloc[:,4:10].sum(axis=1) #axis = 1 means horizontal; 0 means vertical

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False    318  45      49
# 1  2                Ivysaur  Grass  Poison      False    405  60      62
# 2  3               Venusaur  Grass  Poison      False    525  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False    625  80     100
# 4  4             Charmander   Fire     NaN      False    309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1

# %%
#45+49+49+65+65+45 #double check the total
# Out:
# 318

# %%
df.head(5)
#df = df[['Total','HP', 'Defense']] #to grab specific columns and reorder as you want

#df['Total'] = df.iloc[:,4:10].sum(axis=1) #axis = 1 means horizontal; 0 means vertical

# = list(df.columns)
#df = df[cols[0:4] + [cols[-1]]+ cols[4:12]] #-1 is for last column "total" 
#Note: be careful when reordering using these codes 32:10
#df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False    318  45      49
# 1  2                Ivysaur  Grass  Poison      False    405  60      62
# 2  3               Venusaur  Grass  Poison      False    525  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False    625  80     100
# 4  4             Charmander   Fire     NaN      False    309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1

# %%
#saving our data (exporting into desired format. 
#df.to_csv('modified.csv', index=False) # this saves to the directory ie pandas folder with the changes
#df.to_excel('modified.xlsx', index=False)
#df.to_csv('modified.txt', index=False, sep='\t')

# %%
#Filtering data 
#df
#df.loc[df['Type 1'] =='Grass']
#df.loc[(df['Type 1'] =='Grass') & (df['Type 2'] =='Poison')] #| is or & is and
#df.loc[(df['Type 1'] =='Grass') | (df['Type 2'] =='Poison')] #| is or & is and
#you can specify more conditions
#df.loc[(df['Type 1'] =='Grass') & (df['Type 2'] =='Poison') & (df['HP'] > 70)]

# %%
new_df = df.loc[(df['Type 1'] =='Grass') & (df['Type 2'] =='Poison') & (df['HP'] > 70)]

# %%
#new_df # yiu can create a new dataframe using new_df
#new_df.to_csv('filtered.csv') #to save the new dataframe to directory

#new_df = new_df.reset_index()# to reset the index

#new_df = new_df.reset_index(drop=True)  # to get rid of the old indices

#new_df = new_df.reset_index(drop=True, inplace=True)  # if you dont want to reset it to a new dataframe

# %%
#new_df
# Out:
#      #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0    3               Venusaur  Grass  Poison      False    525   80      82
# 1    3  VenusaurMega Venusaur  Grass  Poison      False    625   80     100
# 2   45              Vileplume  Grass  Poison      False    490   75      80
# 3   71             Victreebel  Grass  Poison      False    490   80     105
# 4  591              Amoonguss  Grass  Poison      False    464  114      85
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       83      100      100     80           1
# 1      123      122      120     80           1
# 2       85      110       90     50           1
# 3       65      100       70     70           1
# 4       70       85       80     30           5

# %%
#new_df = df.loc[(df['Type 1'] =='Grass') & (df['Type 2'] =='Poison') & (df['HP'] > 70)]
#to filter all the names that contain 'Mega'
#df
#df.loc[df['Name'].str.contains('Mega')

#df.loc[~df['Name'].str.contains('Mega')] #to do the reverse; drop names that contain "mega"


new_df = df.loc[(df['Type 1'] =='Grass') & (df['Type 2'] =='Poison') & (df['HP'] > 70)]


import re

#df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)] #further filter examples

#df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)] #to ignore uppercase


#to get all pokemon names that start with pi

import re

#df.loc[df['Name'].str.contains('pi[a-z]*', flags=re.I, regex=True)]
#to find names that contain "pi"

#df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)]
#to specify names with "pi" in the middle
# Out:
#        #                 Name    Type 1    Type 2  Legendary  Total   HP  \
# 20    16               Pidgey    Normal    Flying      False    251   40
# 21    17            Pidgeotto    Normal    Flying      False    349   63
# 22    18              Pidgeot    Normal    Flying      False    479   83
# 23    18  PidgeotMega Pidgeot    Normal    Flying      False    579   83
# 30    25              Pikachu  Electric       NaN      False    320   35
# 136  127               Pinsir       Bug       NaN      False    500   65
# 137  127    PinsirMega Pinsir       Bug    Flying      False    600   65
# 186  172                Pichu  Electric       NaN      False    205   20
# 219  204               Pineco       Bug       NaN      False    290   50
# 239  221            Piloswine       Ice    Ground      False    450  100
# 438  393               Piplup     Water       NaN      False    314   53
# 558  499              Pignite      Fire  Fighting      False    418   90
# ...

# %%
#Conditional Changes
#df.loc[df['Type 1'] =='Fire','Type 1'] = 'Flamer' #to change a name in the column. 
#df.loc[df['Type 1'] =='Flamer','Type 1'] = 'Fire'#to change back reverse the names fire and flamer

#df.loc[df['Type 1'] == 'Fire','Legendary'] = True #to make all fire pokemon legendary

# %%
#df


#to revert to modified csv

df = pd.read_csv('modified.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Total  HP  \
# 0      1              Bulbasaur    Grass  Poison      False    318  45
# 1      2                Ivysaur    Grass  Poison      False    405  60
# 2      3               Venusaur    Grass  Poison      False    525  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False    625  80
# 4      4             Charmander     Fire     NaN      False    309  39
# ..   ...                    ...      ...     ...        ...    ...  ..
# 795  719                Diancie     Rock   Fairy       True    600  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True    700  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True    600  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True    680  80
# 799  721              Volcanion     Fire   Water       True    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
#you can modify multiple parameters
#df.loc[df['Total'] > 500, ['Generation', 'Legendary']] = 'TEST VALUE' 
# if total is > 500  then generation and legendary will print out as test value
#df

#df.loc[df['Total'] > 500, ['Generation', 'Legendary']] = 'Test 1','Test 2'
#you can also modify them individually 
#df
# Out:
#        #                   Name   Type 1  Type 2 Legendary  Total  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison     False    318  45      49
# 1      2                Ivysaur    Grass  Poison     False    405  60      62
# 2      3               Venusaur    Grass  Poison    Test 2    525  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison    Test 2    625  80     100
# 4      4             Charmander     Fire     NaN     False    309  39      52
# ..   ...                    ...      ...     ...       ...    ...  ..     ...
# 795  719                Diancie     Rock   Fairy    Test 2    600  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy    Test 2    700  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost    Test 2    600  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark    Test 2    680  80     160
# 799  721              Volcanion     Fire   Water    Test 2    600  80     110
#
# ...

# %%
#df = pd.read_csv('modified.csv')
#df

# %%
#Aggregate Statistics
df = pd.read_csv('modified.csv')
# to see the avergae HP attack
#df.groupby(['Type 1']).mean()

#df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False) 
#to see the highest defense ---steel pokemon has the highest defense

#df.groupby(['Type 1']).mean().sort_values('Attack', ascending=False) #the highest attack - dragon

#df.groupby(['Type 1']).mean().sort_values('HP', ascending=False) #the highest HP - dragon

#df.groupby(['Type 1']).sum() mean, sum and count are aggregate functions

#df.groupby(['Type 1']).count()


#for a  clean count

df['count'] = 1



#df.groupby(['Type 1']).count()['count'] #add a count column to narrow it down to Type 1 only

df.groupby(['Type 1','Type 2']).count()['count'] #to group by multiple parameters at the same time
#this can be used if youre working with a really big dataset
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
#Working with large amounts of data like 20GB
#df =pd.read.csv('modified.csv') to load everything


#for df in pd.read_csv('modified.csv', chunksize=5):
    #print("CHUNK DF")
   # print(df)
# Out:
# CHUNK DF
#    #                   Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False    318  45      49
# 1  2                Ivysaur  Grass  Poison      False    405  60      62
# 2  3               Venusaur  Grass  Poison      False    525  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False    625  80     100
# 4  4             Charmander   Fire     NaN      False    309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1
# CHUNK DF
#    #                       Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 5  5                 Charmeleon   Fire     NaN      False    405  58      64
# ...

# %%
#you can also find some new dataframe
new_df = pd.DataFrame(columns=df.columns) # to create an empty dataframe


for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df, results])
    #this takes your new dataframe as you go through chunks,
    #appends your results and stores it back to new_df #concatenate
